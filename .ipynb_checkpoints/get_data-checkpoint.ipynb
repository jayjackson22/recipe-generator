# %%
from flask import Flask, render_template, redirect, jsonify
from sqlalchemy import create_engine
import pandas as pd
import json

import sqlalchemy as db

connection_string = 'postgres:Adgjmpt1@postresql.cfwwjixawhdl.us-east-2.rds.amazonaws.com:5432/RecipeGenerator'
engine = db.create_engine(f'postgresql://{connection_string}', echo=True)
connection = engine.connect()
metadata = db.MetaData()
# Out:
# 2020-12-03 13:11:45,582 INFO sqlalchemy.engine.base.Engine select version()
# 2020-12-03 13:11:45,585 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 13:11:45,657 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-12-03 13:11:45,658 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 13:11:45,731 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-12-03 13:11:45,732 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 13:11:45,769 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-12-03 13:11:45,770 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 13:11:45,808 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-12-03 13:11:45,810 INFO sqlalchemy.engine.base.Engine {}

# %%
# Recipe
table = db.Table('recipe_list', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
).where(table.columns.id == 1)

result = connection.execute(query).fetchall()
recipe_response = []
for ea in result:
    recipe_response.append(
        {
            "id": ea[0],
            "name": ea[1],
            'description': ea[2],
            'category': ea[3],
            'subcategory': ea[4],
            'prep_time': ea[5],
            'total_time': ea[6],
            'calories': ea[7],
            'hf_id': ea[8],
            'tip': ea[9],
            'image_url': ea[10]
        }
    )
# Out:
# 2020-12-02 10:34:40,816 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2020-12-02 10:34:40,816 INFO sqlalchemy.engine.base.Engine {'table_name': 'recipe_list'}
# 2020-12-02 10:34:40,887 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2020-12-02 10:34:40,887 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:40,926 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2020-12-02 10:34:40,926 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-02 10:34:40,963 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2020-12-02 10:34:40,964 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-02 10:34:41,002 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2020-12-02 10:34:41,003 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:41,040 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2020-12-02 10:34:41,041 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:41,078 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2020-12-02 10:34:41,079 INFO sqlalchemy.engine.base.Engine {'table': 16456}
# 2020-12-02 10:34:41,115 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2020-12-02 10:34:41,116 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:41,155 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2020-12-02 10:34:41,155 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:41,191 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2020-12-02 10:34:41,192 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:41,228 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2020-12-02 10:34:41,228 INFO sqlalchemy.engine.base.Engine {'table_oid': 16456}
# 2020-12-02 10:34:41,301 INFO sqlalchemy.engine.base.Engine SELECT recipe_list.id, recipe_list.name, recipe_list.description, recipe_list.category, recipe_list.subcategory, recipe_list.prep_time, recipe_list.total_time, recipe_list.calories, recipe_list.hf_id, recipe_list.tip, recipe_list.image_url, recipe_list.servings
# FROM recipe_list
# WHERE recipe_list.id = %(id_1)s
# 2020-12-02 10:34:41,302 INFO sqlalchemy.engine.base.Engine {'id_1': 1}

# %%
# Ingredients
table = db.Table('ingredients', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
).where(table.columns.recipe_id == 1)

result = connection.execute(query).fetchall()
ingredients_response = []
for ea in result:
    ingredients_response.append(
        {
            "id": ea[0],
            "recipe_id": ea[1],
            'ingredient_id': ea[2],
            'qty': ea[3],
            'unit': ea[4]
        }
    )
# Out:
# 2020-12-03 13:12:15,963 INFO sqlalchemy.engine.base.Engine SELECT ingredients.id, ingredients.recipe_id, ingredients.ingredient_id, ingredients.qty, ingredients.unit
# FROM ingredients
# WHERE ingredients.recipe_id = %(recipe_id_1)s
# 2020-12-03 13:12:15,964 INFO sqlalchemy.engine.base.Engine {'recipe_id_1': 1}

# %%
# Ingredients Lookup
table = db.Table('ingredients_list', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
)

result = connection.execute(query).fetchall()
ingredients_list_response = []
for ea in result:
    ingredients_list_response.append(
        {
            "id": ea[0],
            "ingredient": ea[1],
            'category': ea[2],
            'subcategory': ea[3],
            'staple': ea[4]
        }
    )
# Out:
# 2020-12-03 13:12:20,226 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2020-12-03 13:12:20,227 INFO sqlalchemy.engine.base.Engine {'table_name': 'ingredients_list'}
# 2020-12-03 13:12:20,305 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2020-12-03 13:12:20,305 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,349 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2020-12-03 13:12:20,350 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 13:12:20,422 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2020-12-03 13:12:20,423 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 13:12:20,472 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2020-12-03 13:12:20,473 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,518 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2020-12-03 13:12:20,519 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,558 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2020-12-03 13:12:20,559 INFO sqlalchemy.engine.base.Engine {'table': 16448}
# 2020-12-03 13:12:20,601 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2020-12-03 13:12:20,602 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,650 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2020-12-03 13:12:20,651 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,694 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2020-12-03 13:12:20,696 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,735 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2020-12-03 13:12:20,737 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-03 13:12:20,813 INFO sqlalchemy.engine.base.Engine SELECT ingredients_list.id, ingredients_list.ingredient, ingredients_list.category, ingredients_list.subcategory, ingredients_list.staple
# FROM ingredients_list
# 2020-12-03 13:12:20,814 INFO sqlalchemy.engine.base.Engine {}

# %%
ingredients_df = pd.DataFrame(ingredients_response)
ingredients_list_df = pd.DataFrame(ingredients_list_response)

# %%
ingr_df = ingredients_df.merge(ingredients_list_df, left_on='ingredient_id', right_on='id')

# %%
ingr_df = ingr_df[['ingredient','qty','unit','servings']]
ingr_df

# %%
res = ingr_df.to_json(orient="records")
parsed = json.loads(res)
parsed

# %%
recipe_response[0]['ingredients'] = parsed

# %%
recipe_response

# %%
#########
# Steps #
#########
table = db.Table('steps', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
).where(table.columns.recipe_id == 1)

result = connection.execute(query).fetchall()
steps_response = []
for ea in result:
    steps_response.append(
        {
            "id": ea[0],
            "recipe_id": ea[1],
            'step': ea[2],
            'title': ea[3],
            'description': ea[4]
        }
    )
# Out:
# 2020-12-03 11:04:00,729 INFO sqlalchemy.engine.base.Engine SELECT steps.id, steps.recipe_id, steps.step, steps.title, steps.description
# FROM steps
# WHERE steps.recipe_id = %(recipe_id_1)s
# 2020-12-03 11:04:00,730 INFO sqlalchemy.engine.base.Engine {'recipe_id_1': 1}

# %%
# Steps images - Entire list, not filtered
table = db.Table('steps_images', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
)

result = connection.execute(query).fetchall()
steps_images_response = []
for ea in result:
    steps_images_response.append(
        {
            "id": ea[0],
            "step_id": ea[1],
            "image_url": ea[2]
        }
    )
# Out:
# 2020-12-03 11:20:55,665 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2020-12-03 11:20:55,666 INFO sqlalchemy.engine.base.Engine {'table_name': 'steps_images'}
# 2020-12-03 11:20:55,738 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2020-12-03 11:20:55,738 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:55,776 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2020-12-03 11:20:55,776 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 11:20:55,812 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2020-12-03 11:20:55,813 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-03 11:20:55,850 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2020-12-03 11:20:55,851 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:55,887 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2020-12-03 11:20:55,888 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:55,923 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2020-12-03 11:20:55,924 INFO sqlalchemy.engine.base.Engine {'table': 16478}
# 2020-12-03 11:20:55,959 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2020-12-03 11:20:55,960 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:55,996 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2020-12-03 11:20:55,997 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:56,034 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2020-12-03 11:20:56,035 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:56,072 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2020-12-03 11:20:56,073 INFO sqlalchemy.engine.base.Engine {'table_oid': 16478}
# 2020-12-03 11:20:56,144 INFO sqlalchemy.engine.base.Engine SELECT steps_images.id, steps_images.step_id, steps_images.image_url
# FROM steps_images
# 2020-12-03 11:20:56,145 INFO sqlalchemy.engine.base.Engine {}

# %%
for step in steps_response:
    imgs = []
    for image in steps_images_response:
        if (step['id'] == image['id']):
            imgs.append(image['image_url'])
    step['images'] =  imgs
