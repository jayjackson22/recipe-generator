# %%
from flask import Flask, render_template, redirect, jsonify
from sqlalchemy import create_engine
import pandas as pd
import json

import sqlalchemy as db

connection_string = 'postgres:Adgjmpt1@postresql.cfwwjixawhdl.us-east-2.rds.amazonaws.com:5432/RecipeGenerator'
engine = db.create_engine(f'postgresql://{connection_string}', echo=True)
connection = engine.connect()
metadata = db.MetaData()
# Out:
# 2020-12-01 23:09:17,200 INFO sqlalchemy.engine.base.Engine select version()
# 2020-12-01 23:09:17,201 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 23:09:17,270 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-12-01 23:09:17,271 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 23:09:17,343 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-12-01 23:09:17,344 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 23:09:17,379 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-12-01 23:09:17,379 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 23:09:17,413 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-12-01 23:09:17,414 INFO sqlalchemy.engine.base.Engine {}

# %%
# Recipe
table = db.Table('recipe_list', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
).where(table.columns.id == 1)

result = connection.execute(query).fetchall()
recipe_response = []
for ea in result:
    recipe_response.append(
        {
            "id": ea[0],
            "name": ea[1],
            'description': ea[2],
            'category': ea[3],
            'subcategory': ea[4],
            'prep_time': ea[5],
            'total_time': ea[6],
            'calories': ea[7],
            'hf_id': ea[8],
            'tip': ea[9],
            'image_url': ea[10]
        }
    )
# Out:
# 2020-12-01 23:09:41,100 INFO sqlalchemy.engine.base.Engine SELECT recipe_list.id, recipe_list.name, recipe_list.description, recipe_list.category, recipe_list.subcategory, recipe_list.prep_time, recipe_list.total_time, recipe_list.calories, recipe_list.hf_id, recipe_list.tip, recipe_list.image_url, recipe_list.servings
# FROM recipe_list
# WHERE recipe_list.id = %(id_1)s
# 2020-12-01 23:09:41,101 INFO sqlalchemy.engine.base.Engine {'id_1': 1}

# %%
recipe_df
# Out:
#    id                                    name  \
# 0   1  Tuscan Pork Sausage & Pepper Spaghetti
#
#                                          description category subcategory  \
# 0  Tuscan Heat Spice: Our blend of aromatic, Ital...  Italian       Pasta
#
#    prep_time  total_time  calories        hf_id  \
# 0         10          35       910  WK 37 TX-03
#
#                                                  tip  \
# 0  Our preferred technique for removing sausage c...
#
#                                            image_url
# 0  https://recipe-images-jj.s3.us-east-2.amazonaw...

# %%
# Ingredients

# Recipe
table = db.Table('ingredients', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
).where(table.columns.recipe_id == 1)

result = connection.execute(query).fetchall()
ingredients_response = []
for ea in result:
    ingredients_response.append(
        {
            "id": ea[0],
            "recipe_id": ea[1],
            'ingredient_id': ea[2],
            'qty': ea[3],
            'unit': ea[4],
            'servings': ea[5]
        }
    )
# Out:
# 2020-12-01 22:59:47,586 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2020-12-01 22:59:47,587 INFO sqlalchemy.engine.base.Engine {'table_name': 'ingredients'}
# 2020-12-01 22:59:47,659 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2020-12-01 22:59:47,660 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:47,697 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2020-12-01 22:59:47,698 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 22:59:47,734 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2020-12-01 22:59:47,735 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 22:59:47,773 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2020-12-01 22:59:47,774 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:47,811 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2020-12-01 22:59:47,812 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:47,849 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2020-12-01 22:59:47,850 INFO sqlalchemy.engine.base.Engine {'table': 16440}
# 2020-12-01 22:59:47,889 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2020-12-01 22:59:47,890 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:47,930 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2020-12-01 22:59:47,932 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:47,971 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2020-12-01 22:59:47,972 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:48,014 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2020-12-01 22:59:48,015 INFO sqlalchemy.engine.base.Engine {'table_oid': 16440}
# 2020-12-01 22:59:48,090 INFO sqlalchemy.engine.base.Engine SELECT ingredients.id, ingredients.recipe_id, ingredients.ingredient_id, ingredients.qty, ingredients.unit, ingredients.servings
# FROM ingredients
# WHERE ingredients.recipe_id = %(recipe_id_1)s
# 2020-12-01 22:59:48,091 INFO sqlalchemy.engine.base.Engine {'recipe_id_1': 1}

# %%
# Ingredients Lookup

# Recipe
table = db.Table('ingredients_list', metadata, autoload = True, autoload_with = engine)
query = db.select(
    [
        table
    ]
)

result = connection.execute(query).fetchall()
ingredients_list_response = []
for ea in result:
    ingredients_list_response.append(
        {
            "id": ea[0],
            "ingredient": ea[1],
            'category': ea[2],
            'subcategory': ea[3],
            'staple': ea[4]
        }
    )
# Out:
# 2020-12-01 22:59:52,356 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2020-12-01 22:59:52,358 INFO sqlalchemy.engine.base.Engine {'table_name': 'ingredients_list'}
# 2020-12-01 22:59:52,428 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2020-12-01 22:59:52,429 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:52,466 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2020-12-01 22:59:52,467 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 22:59:52,505 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2020-12-01 22:59:52,506 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-01 22:59:52,546 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2020-12-01 22:59:52,546 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:52,584 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2020-12-01 22:59:52,585 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:52,621 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2020-12-01 22:59:52,621 INFO sqlalchemy.engine.base.Engine {'table': 16448}
# 2020-12-01 22:59:52,661 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2020-12-01 22:59:52,662 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:52,702 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2020-12-01 22:59:52,703 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:52,885 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2020-12-01 22:59:52,886 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:53,202 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2020-12-01 22:59:53,202 INFO sqlalchemy.engine.base.Engine {'table_oid': 16448}
# 2020-12-01 22:59:53,277 INFO sqlalchemy.engine.base.Engine SELECT ingredients_list.id, ingredients_list.ingredient, ingredients_list.category, ingredients_list.subcategory, ingredients_list.staple
# FROM ingredients_list
# 2020-12-01 22:59:53,278 INFO sqlalchemy.engine.base.Engine {}

# %%
ingredients_df = pd.DataFrame(ingredients_response)
ingredients_list_df = pd.DataFrame(ingredients_list_response)

# %%
ingr_df = ingredients_df.merge(ingredients_list_df, left_on='ingredient_id', right_on='id')

# %%
ingr_df = ingr_df[['ingredient','qty','unit','servings']]
ingr_df
# Out:
#                    ingredient    qty unit  servings
# 0                     Parsley   0.25   oz         2
# 1        Italian Pork Sausage   9.00   oz         2
# 2           Tuscan Heat Spice   1.00    T         2
# 3                   Spaghetti   6.00   oz         2
# 4            Crushed Tomatoes  13.76   oz         2
# 5   Chicken Stock Concentrate   2.00    t         2
# 6             Parmesan Cheese   0.25    c         2
# 7                        Salt   1.00   ea         2
# 8                      Pepper   1.00   ea         2
# 9               Vegetable Oil   1.00    T         2
# 10                     Butter   1.00    T         2
# 11               Yellow Onion   0.50   ea         2
# 12                Bell Pepper   0.50   ea         2

# %%
res = ingr_df.to_json(orient="records")
parsed = json.loads(res)
parsed
# Out:
# [{'ingredient': 'Parsley', 'qty': 0.25, 'unit': 'oz', 'servings': 2},
#  {'ingredient': 'Italian Pork Sausage',
#   'qty': 9.0,
#   'unit': 'oz',
#   'servings': 2},
#  {'ingredient': 'Tuscan Heat Spice', 'qty': 1.0, 'unit': 'T', 'servings': 2},
#  {'ingredient': 'Spaghetti', 'qty': 6.0, 'unit': 'oz', 'servings': 2},
#  {'ingredient': 'Crushed Tomatoes', 'qty': 13.76, 'unit': 'oz', 'servings': 2},
#  {'ingredient': 'Chicken Stock Concentrate',
#   'qty': 2.0,
#   'unit': 't',
#   'servings': 2},
#  {'ingredient': 'Parmesan Cheese', 'qty': 0.25, 'unit': 'c', 'servings': 2},
#  {'ingredient': 'Salt', 'qty': 1.0, 'unit': 'ea', 'servings': 2},
#  {'ingredient': 'Pepper', 'qty': 1.0, 'unit': 'ea', 'servings': 2},
#  {'ingredient': 'Vegetable Oil', 'qty': 1.0, 'unit': 'T', 'servings': 2},
#  {'ingredient': 'Butter', 'qty': 1.0, 'unit': 'T', 'servings': 2},
#  {'ingredient': 'Yellow Onion', 'qty': 0.5, 'unit': 'ea', 'servings': 2},
#  {'ingredient': 'Bell Pepper', 'qty': 0.5, 'unit': 'ea', 'servings': 2}]

# %%
recipe_response[0]['ingredients'] = parsed

# %%
recipe_response
# Out:
# [{'id': 1,
#   'name': 'Tuscan Pork Sausage & Pepper Spaghetti',
#   'description': 'Tuscan Heat Spice: Our blend of aromatic, Italian-style herbs also packs a peppery punch.',
#   'category': 'Italian',
#   'subcategory': 'Pasta',
#   'prep_time': 10,
#   'total_time': 35,
#   'calories': 910,
#   'hf_id': 'WK 37 TX-03',
#   'tip': 'Our preferred technique for removing sausage casing, as you will in step 1? Using the tip of your knife, make a shallow slit along the length of the sausage, then peel away and discard the casing.',
#   'image_url': 'https://recipe-images-jj.s3.us-east-2.amazonaws.com/title-images/WK+26+TX-08.jpg',
#   'ingredients': [{'ingredient': 'Parsley',
#     'qty': 0.25,
#     'unit': 'oz',
#     'servings': 2},
#    {'ingredient': 'Italian Pork Sausage',
#     'qty': 9.0,
#     'unit': 'oz',
#     'servings': 2},
#    {'ingredient': 'Tuscan Heat Spice', 'qty': 1.0, 'unit': 'T', 'servings': 2},
#    {'ingredient': 'Spaghetti', 'qty': 6.0, 'unit': 'oz', 'servings': 2},
#    {'ingredient': 'Crushed Tomatoes',
#     'qty': 13.76,
#     'unit': 'oz',
#     'servings': 2},
#    {'ingredient': 'Chicken Stock Concentrate',
#     'qty': 2.0,
#     'unit': 't',
#     'servings': 2},
#    {'ingredient': 'Parmesan Cheese', 'qty': 0.25, 'unit': 'c', 'servings': 2},
#    {'ingredient': 'Salt', 'qty': 1.0, 'unit': 'ea', 'servings': 2},
#    {'ingredient': 'Pepper', 'qty': 1.0, 'unit': 'ea', 'servings': 2},
#    {'ingredient': 'Vegetable Oil', 'qty': 1.0, 'unit': 'T', 'servings': 2},
#    {'ingredient': 'Butter', 'qty': 1.0, 'unit': 'T', 'servings': 2},
#    {'ingredient': 'Yellow Onion', 'qty': 0.5, 'unit': 'ea', 'servings': 2},
#    {'ingredient': 'Bell Pepper', 'qty': 0.5, 'unit': 'ea', 'servings': 2}]}]
